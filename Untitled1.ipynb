# %%
# import matplotlib.pyplot as plt 
# import pandas as pd 
# file = pd.read_excel('data.xlsx') 
# x_axis = file['X values'] 
# y_axis = file['Y values'] 
# plt.bar(x_axis, y_axis, width=5) 
# plt.xlabel("X-Axis") 
# plt.ylabel("Y-Axis") 
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel(r"C:\Users\HP\OneDrive\Documents\prasanna\New Microsoft Excel Worksheet (2).xlsx",sheet_name="Sheet1")
df
# Out:
#      Municipal corporation No.of delivery units No.of Anna canteens  \
# 0  Municipal corporation 1          Gow_down -1           Canteen-1
# 1  Municipal corporation 1          Gow_down -1           Canteen-1
# 2  Municipal corporation 1          Gow_down -1           Canteen-1
# 3  Municipal corporation 1          Gow_down -1           Canteen-2
# 4  Municipal corporation 1          Gow_down -1           Canteen-2
# 5  Municipal corporation 1          Gow_down -1           Canteen-2
#
#             Time  No.of customers  Total available food plates  \
# 0  12.00-1.00 PM               80                          300
# 1   1.00-2.00 PM              130                          220
# 2   2.00-3.00 PM               80                           90
# 3  12.00-1.00 PM               60                          250
# 4   1.00-2.00 PM               90                          190
# 5   2.00-3.00 PM               70                          100
#
# ...

# %%
df.head()
# Out:
#      Municipal corporation No.of delivery units No.of Anna canteens  \
# 0  Municipal corporation 1          Gow_down -1           Canteen-1
# 1  Municipal corporation 1          Gow_down -1           Canteen-1
# 2  Municipal corporation 1          Gow_down -1           Canteen-1
# 3  Municipal corporation 1          Gow_down -1           Canteen-2
# 4  Municipal corporation 1          Gow_down -1           Canteen-2
#
#             Time  No.of customers  Total available food plates  \
# 0  12.00-1.00 PM               80                          300
# 1   1.00-2.00 PM              130                          220
# 2   2.00-3.00 PM               80                           90
# 3  12.00-1.00 PM               60                          250
# 4   1.00-2.00 PM               90                          190
#
#    No.of plates consumed  No.of feedbacks received  No.of +ve feedbacks  \
# 0                     80                         5                    4
# ...

# %%
df.tail()
# Out:
#      Municipal corporation No.of delivery units No.of Anna canteens  \
# 1  Municipal corporation 1          Gow_down -1           Canteen-1
# 2  Municipal corporation 1          Gow_down -1           Canteen-1
# 3  Municipal corporation 1          Gow_down -1           Canteen-2
# 4  Municipal corporation 1          Gow_down -1           Canteen-2
# 5  Municipal corporation 1          Gow_down -1           Canteen-2
#
#             Time  No.of customers  Total available food plates  \
# 1   1.00-2.00 PM              130                          220
# 2   2.00-3.00 PM               80                           90
# 3  12.00-1.00 PM               60                          250
# 4   1.00-2.00 PM               90                          190
# 5   2.00-3.00 PM               70                          100
#
#    No.of plates consumed  No.of feedbacks received  No.of +ve feedbacks  \
# 1                    130                         2                    2
# ...

# %%
df.dtypes
# Out:
# Municipal corporation          object
# No.of delivery units           object
# No.of Anna canteens            object
# Time                           object
# No.of customers                 int64
# Total available food plates     int64
# No.of plates consumed           int64
# No.of feedbacks received        int64
# No.of +ve feedbacks             int64
# No.of -ve feedbacks             int64
# Food weight@Gow down           object
# Food weight @Anna canteen      object
# No.of Donations                 int64
# Total Donation Amount           int64
# Top 5 donators                 object
# No. of employs                  int64
# Total generated tokens          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Municipal corporation', 'No.of delivery units', 'No.of Anna canteens',
#        'Time', 'No.of customers', 'Total available food plates',
#        'No.of plates consumed', 'No.of feedbacks received',
#        'No.of +ve feedbacks', 'No.of -ve feedbacks', 'Food weight@Gow down',
#        'Food weight @Anna canteen', 'No.of Donations', 'Total Donation Amount',
#        'Top 5 donators', 'No. of employs', 'Total generated tokens'],
#       dtype='object')

# %%
df.plot(kind='bar',
        x='No.of customers',
        y='Total available food plates',
        color='green')

plt.title('anna_canteen_donations')


plt.show()

# %%
df.plot(x='No.of customers', y=['Total available food plates','No.of plates consumed'],
        kind="bar", figsize=(10, 10))
# Out:
# <Axes: xlabel='No.of customers'>

# %%
df[['Municipal corporation', 'No.of delivery units', 'No.of Anna canteens','Time', 'No.of customers', 'Total available food plates','No.of plates consumed']].plot(x='Time',kind='bar')
# Out:
# <Axes: xlabel='Time'>

# %%
df[['Municipal corporation', 'No.of delivery units', 'No.of Anna canteens','Time', 'No.of customers', 'Total available food plates','No.of plates consumed']].plot(x='Time',kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Time'>

# %%
df[['Municipal corporation', 'No.of delivery units', 'No.of Anna canteens','Time', 'No.of customers', 'Total available food plates','No.of plates consumed']].plot(x='No.of Anna canteens',kind='bar',stacked=True,
color=['red','green','pink'])
# Out:
# <Axes: xlabel='No.of Anna canteens'>

# %%
plt.plot(['No.of customers','Total available food plates'])
plt.show()

# %%
df.set_index('No.of Anna canteens', inplace=True)

# Pie chart
df.plot(kind='pie', y='Total generated tokens',autopct='%1.1f%%', startangle=150,legend=False)
plt.title('canteen ratings')
plt.show()

# %%
df.plot.area(stacked=False);

# %%
df.plot.barh(stacked=True);
